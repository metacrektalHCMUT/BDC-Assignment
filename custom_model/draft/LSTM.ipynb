# %%
import io
import os
import re
import shutil
import string
import tensorflow as tf
from tqdm import tqdm

#use for naive_bayes
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,SnowballStemmer
from nltk.tokenize import TweetTokenizer
import pdb
from nltk.corpus import twitter_samples
import numpy as np
import pandas as pd
import nltk
from os import getcwd

from tensorflow.keras import layers
from tensorflow.keras import losses

nltk.download('stopwords')

#use for LSTM and WordEmbedding Model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Dropout, LSTM, Activation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.initializers import glorot_uniform
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from  nltk.stem import SnowballStemmer

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')

train_dir = os.path.join(dataset_dir, 'train')
os.listdir(train_dir)
remove_dir = os.path.join(train_dir, 'unsup')
shutil.rmtree(remove_dir)

# %% [markdown]
# #NEW DATA

# %%
batch_size = 32
raw_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    "aclImdb/train",
    batch_size=batch_size,
    validation_split=0.2,
    subset="training",
    seed=42
)

raw_val_ds = tf.keras.preprocessing.text_dataset_from_directory(
    "aclImdb/test",
    batch_size=batch_size,
    validation_split=0.2,
    subset="validation",
    seed=42
)

raw_test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    "aclImdb/test",
    batch_size=batch_size
)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Found 25000 files belonging to 2 classes.

# %%
def custom_standardization(input_data):
  lowercase = tf.strings.lower(input_data)
  stripped_html = tf.strings.regex_replace(lowercase, '<br />', ' ')
  return tf.strings.regex_replace(stripped_html,
                                  '[%s]' % re.escape(string.punctuation),
                                  '')

x = []
y = []
for text_batch, label_batch in raw_train_ds.take(len(raw_train_ds)):
    for i in range(len(text_batch)):
        x.append(custom_standardization(text_batch[i]).numpy().decode("utf-8"))
        y.append(int(label_batch[i].numpy().item()))

for text_batch, label_batch in raw_test_ds.take(len(raw_test_ds)):
    for i in range(len(text_batch)):
        x.append(custom_standardization(text_batch[i]).numpy().decode("utf-8"))
        y.append(int(label_batch[i].numpy().item()))

# %%
size_train = int(0.8 * len(x))
size_test = int(0.8 * len(y))

train_x = np.array(x[:size_train])
train_y = np.array(y[:size_train])

test_x = np.array(x[size_train:])
test_y = np.array(y[size_train:])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_x)

x_train = pad_sequences(tokenizer.texts_to_sequences(train_x), maxlen = 250)
x_test = pad_sequences(tokenizer.texts_to_sequences(test_x), maxlen = 250)

# %%
#create y_data
encoder = LabelEncoder()
encoder.fit(train_y)

y_train = encoder.transform(train_y)
y_test = encoder.transform(test_y)
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
def read_glove_vecs(glove_file):
    with open(glove_file, 'r') as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.add(curr_word)
            word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
        
        i = 1
        words_to_index = {}
        index_to_words = {}
        for w in sorted(words):
            words_to_index[w] = i
            index_to_words[i] = w
            i = i + 1
    return words_to_index, index_to_words, word_to_vec_map

word_to_index, index_to_word, word_to_vec_map = read_glove_vecs('/content/drive/MyDrive/Big_Data/custom_model/glove/glove.6B.50d.txt')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def sentences_to_indices(X,word_to_index,max_len):
    m = len(X) #number training_example

    X_indices = np.zeros((m,max_len))
    for i in tqdm(range(m)):
        j = 0
        for w in X[i]:
            if w in word_to_index:
               X_indices[i,j] = word_to_index[w]
               j = j + 1
    return X_indices

def pretrained_embedding_layer(word_to_vec_map,word_to_index): 
    any_word = list(word_to_vec_map.keys())[0]
    emb_dim = word_to_vec_map[any_word].shape[0]
    vocab_size = len(word_to_index) + 1

    #Initialize the embedding matrix
    emb_matrix = np.zeros((vocab_size, emb_dim))

    for word, idx in word_to_index.items():
        emb_matrix[idx, :] = word_to_vec_map[word]
    embedding_layer = Embedding(vocab_size,emb_dim, input_length=250, trainable = False)
    embedding_layer.build((None,))        

    embedding_layer.set_weights([emb_matrix])

    return embedding_layer

embedding_layer = pretrained_embedding_layer(word_to_vec_map,word_to_index)

model_LSTM = tf.keras.Sequential([
    tf.keras.Input((250,),dtype = 'int32'),
    embedding_layer,
    tf.keras.layers.LSTM(128,return_sequences = True),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.LSTM(128,return_sequences = False),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1,activation = 'sigmoid')
])

model_LSTM.summary()
model_LSTM.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 250, 50)           20000050
#
#  lstm_2 (LSTM)               (None, 250, 128)          91648
#
#  dropout_2 (Dropout)         (None, 250, 128)          0
#
#  lstm_3 (LSTM)               (None, 128)               131584
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 20,223,411
# Trainable params: 223,361
# Non-trainable params: 20,000,050
# _________________________________________________________________

# %%
history = model_LSTM.fit(
    x_train,
    y_train, 
    epochs = 30,
    validation_split = 0.1,
    verbose = 1,
    shuffle = True 
    )
# Out:
# Epoch 1/30
# 1013/1013 [==============================] - 98s 94ms/step - loss: 0.6828 - accuracy: 0.5573 - val_loss: 0.6675 - val_accuracy: 0.5861
# Epoch 2/30
# 1013/1013 [==============================] - 92s 90ms/step - loss: 0.6526 - accuracy: 0.6156 - val_loss: 0.6113 - val_accuracy: 0.6639
# Epoch 3/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.5999 - accuracy: 0.6814 - val_loss: 0.5501 - val_accuracy: 0.7200
# Epoch 4/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.5394 - accuracy: 0.7307 - val_loss: 0.5623 - val_accuracy: 0.7094
# Epoch 5/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.4842 - accuracy: 0.7687 - val_loss: 0.4564 - val_accuracy: 0.7792
# Epoch 6/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.4320 - accuracy: 0.8014 - val_loss: 0.6769 - val_accuracy: 0.6697
# Epoch 7/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.3910 - accuracy: 0.8258 - val_loss: 0.4522 - val_accuracy: 0.7794
# Epoch 8/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.3496 - accuracy: 0.8467 - val_loss: 0.3869 - val_accuracy: 0.8225
# Epoch 9/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.3258 - accuracy: 0.8588 - val_loss: 0.3913 - val_accuracy: 0.8147
# Epoch 10/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.2906 - accuracy: 0.8756 - val_loss: 0.3705 - val_accuracy: 0.8319
# Epoch 11/30
# 1013/1013 [==============================] - 91s 89ms/step - loss: 0.2553 - accuracy: 0.8935 - val_loss: 0.4051 - val_accuracy: 0.8242
# Epoch 12/30
# 1013/1013 [==============================] - 91s 89ms/step - loss: 0.2351 - accuracy: 0.9048 - val_loss: 0.4589 - val_accuracy: 0.8325
# Epoch 13/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.1975 - accuracy: 0.9216 - val_loss: 0.4333 - val_accuracy: 0.8286
# Epoch 14/30
# 1013/1013 [==============================] - 92s 90ms/step - loss: 0.1718 - accuracy: 0.9323 - val_loss: 0.4587 - val_accuracy: 0.8286
# Epoch 15/30
# 1013/1013 [==============================] - 91s 89ms/step - loss: 0.1504 - accuracy: 0.9419 - val_loss: 0.5061 - val_accuracy: 0.8289
# Epoch 16/30
# 1013/1013 [==============================] - 91s 89ms/step - loss: 0.1254 - accuracy: 0.9527 - val_loss: 0.6546 - val_accuracy: 0.7997
# Epoch 17/30
# 1013/1013 [==============================] - 90s 89ms/step - loss: 0.1101 - accuracy: 0.9600 - val_loss: 0.5987 - val_accuracy: 0.8289
# Epoch 18/30
# 1013/1013 [==============================] - 91s 89ms/step - loss: 0.0974 - accuracy: 0.9640 - val_loss: 0.5594 - val_accuracy: 0.8294
# Epoch 19/30
# 1013/1013 [==============================] - 92s 91ms/step - loss: 0.0839 - accuracy: 0.9703 - val_loss: 0.6978 - val_accuracy: 0.8267
# Epoch 20/30
# 1013/1013 [==============================] - 91s 89ms/step - loss: 0.0787 - accuracy: 0.9724 - val_loss: 0.6622 - val_accuracy: 0.8031
# Epoch 21/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.0706 - accuracy: 0.9757 - val_loss: 0.7155 - val_accuracy: 0.8272
# Epoch 22/30
# 1013/1013 [==============================] - 91s 89ms/step - loss: 0.0604 - accuracy: 0.9790 - val_loss: 0.6933 - val_accuracy: 0.8297
# Epoch 23/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.0572 - accuracy: 0.9808 - val_loss: 0.7508 - val_accuracy: 0.8158
# Epoch 24/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.0583 - accuracy: 0.9802 - val_loss: 0.8065 - val_accuracy: 0.8200
# Epoch 25/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.0494 - accuracy: 0.9835 - val_loss: 0.7914 - val_accuracy: 0.8194
# Epoch 26/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.0493 - accuracy: 0.9834 - val_loss: 0.7779 - val_accuracy: 0.8231
# Epoch 27/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.0440 - accuracy: 0.9853 - val_loss: 0.8600 - val_accuracy: 0.8175
# Epoch 28/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.0430 - accuracy: 0.9860 - val_loss: 0.7825 - val_accuracy: 0.8281
# Epoch 29/30
# 1013/1013 [==============================] - 91s 89ms/step - loss: 0.0496 - accuracy: 0.9826 - val_loss: 0.7906 - val_accuracy: 0.8253
# Epoch 30/30
# 1013/1013 [==============================] - 91s 90ms/step - loss: 0.0440 - accuracy: 0.9849 - val_loss: 0.7699 - val_accuracy: 0.8239

# %%
loss, accuracy = model_LSTM.evaluate(x_test,y_test)

print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 282/282 [==============================] - 12s 41ms/step - loss: 1.1374 - accuracy: 0.7449
# Loss:  1.1373573541641235
# Accuracy:  0.7448889017105103

# %%
history_dict = model_LSTM.history

import matplotlib.pyplot as plt

acc = history_dict['binary_accuracy']
val_acc = history_dict['val_binary_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-47ab47ac83c5> in <module>()
# ----> 1 history_dict = model_LSTM.history()
#       2
#       3 import matplotlib.pyplot as plt
#       4
#       5 acc = history_dict['binary_accuracy']
#
# TypeError: 'History' object is not callable

# %%
history_dict.
# Out:
# {'epochs': 1, 'steps': 282, 'verbose': 1}
